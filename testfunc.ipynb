# %%
import numpy as np
import pandas as pd
from functions import generate_ar, fit_ar_ols #, fit_ar_ML_normal

# %%
data = generate_ar(steps=100000, paths=10, a=np.array([0.2, 0.9, 0.1]), start=0, dist='normal', error_var=1)
# Out:
# 100%|██████████| 99998/99998 [00:01<00:00, 79129.35it/s]
# 10 different AR(2) processes of 100000 steps have been generated with increments following normal distribution

# %%
fit_ar_ols(data, 2)
# Out:
# array([[0.19155122, 0.19684786, 0.19742302, 0.20212991, 0.19763201,
#         0.19168587, 0.19658853, 0.19872049, 0.20318258, 0.20704179],
#        [0.89930004, 0.8965453 , 0.9024602 , 0.89894082, 0.90004415,
#         0.89494026, 0.89427117, 0.89974018, 0.89660795, 0.89864293],
#        [0.10070031, 0.10345527, 0.09754006, 0.10105936, 0.09995544,
#         0.10506056, 0.10572975, 0.10026026, 0.10339189, 0.10135655]])
