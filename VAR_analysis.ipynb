# %% [markdown]
# # Vector AutoRegressive Models

# %%
import numpy as np
import pandas as pd

import functions.vectorautoregressive as var
import functions.autoregressive as ar

# %%
A = var.generate_A_stationary(k=3, p=5)
sigma = var.generate_sigma(k=3, bounds=(0.1,1))

data = var.generate_var(T=100000, k=3, p=5, sigma=sigma, A=A)
# Out:
# 100%|██████████| 99995/99995 [00:00<00:00, 229502.52it/s]

# %%
ar.plot_paths(data, title='VAR processes')
